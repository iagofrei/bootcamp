# %% [markdown]
# # Aula 02

# %% [markdown]
# ## Instalando as bibliotecas necessárias
#
# Antes de começar, precisamos importar as bibliotecas necessárias

# %%
# !pip install pandas
# !pip install Faker

# %% [markdown]
# ## Modelagem de tabelas especializadas com dados agrupados e/ou sumarizados.

# %%
import pandas as pd

# esse comando faz as tabelas mostrarem mais colunas, ao inves de ter uns 3 pontinhos no final, esse estaria mostrando as 50 colunas
pd.set_option('display.max_columns',50)

# %%
path = '../data_analytics_engineering/dados/aula2/sales/sales_data_sample.csv'

sales_df = pd.read_csv(path, encoding="ansi")

# %%
# Mostra uma quantidade de linhas da tabela (como dentro do parentes esta sem nada, por padrão mostra as 5 1ªs linhas)
sales_df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES
# 0        10107               30      95.70                2  2871.00  \
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95  \
# 1    5/7/2003 0:00  Shipped       2         5     2003  Motorcycles    95
# 2    7/1/2003 0:00  Shipped       3         7     2003  Motorcycles    95
# 3   8/25/2003 0:00  Shipped       3         8     2003  Motorcycles    95
# 4  10/10/2003 0:00  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE
# ...

# %%
# Mostra uma quantidade de linhas da tabela (como dentro do parentes esta com o numero 10, vai mostrar as 1ªs 10 linhas)
sales_df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES
# 0        10107               30      95.70                2  2871.00  \
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95  \
# ...

# %%
# Mostra as ultimas linhas da tabela (como dentro do parentes esta sem nada, por padrão mostra as 5 ultimas linhas)
sales_df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES
# 2818        10350               20     100.00               15  2244.40  \
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID PRODUCTLINE  MSRP
# 2818  12/2/2004 0:00   Shipped       4        12     2004       Ships    54  \
# 2819  1/31/2005 0:00   Shipped       1         1     2005       Ships    54
# 2820   3/1/2005 0:00  Resolved       1         3     2005       Ships    54
# 2821  3/28/2005 0:00   Shipped       1         3     2005       Ships    54
# 2822   5/6/2005 0:00   On Hold       2         5     2005       Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME           PHONE
# ...

# %%
# Mostra dados da tabela (ele descreve as colunas da tabela)
sales_df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER
# count   2823.000000      2823.000000  2823.000000      2823.000000  \
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
# o isna retorna um booleano se os campos estão nulos e o sum soma isso
sales_df.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %% [markdown]
# ### Criando um dataset manualmente

# %%
json = { "nome": ["Maria", "João"], "idade": ["30", "40"]}

df_1 = pd.DataFrame(json)
df_1
# Out:
#     nome idade
# 0  Maria    30
# 1   João    40

# %% [markdown]
# ### Criando um dataset fake

# %%
from faker import Faker
fake = Faker()

# %%
nascimentos = []
nomes = []
emails = []

for i in range(10):
    nascimentos.append(fake.date())
    nomes.append(fake.name())
    emails.append(fake.email())

df_fake = pd.DataFrame(
    {
        'nome': nomes,
        'data_nascimento': nascimentos,
        'email': emails
    }
)
df_fake
# Out:
#                    nome data_nascimento                         email
# 0        Kimberly Stone      2011-05-14          kdouglas@example.org
# 1            Jesse Buck      1981-01-27         tiffany36@example.net
# 2         Emily Johnson      2004-06-24   randallthompson@example.org
# 3         Russell Black      1991-01-21        vegarobert@example.com
# 4     Christopher Evans      1984-09-13       martindavid@example.org
# 5            Susan Rice      2023-01-15        payneshaun@example.org
# 6        Martin Sanders      2017-03-17  christensenlinda@example.com
# 7       Alicia Matthews      2022-12-08         rbartlett@example.org
# 8        James Santiago      1992-06-22          ronald52@example.net
# 9  Christopher Anderson      1979-07-27         shannon40@example.net

# %%
fake_df = pd.DataFrame({
    'nome': [fake.name() for i in range(10)],
    'data_nascimento': [fake.date() for i in range(10)],
    'email': [fake.email() for i in range(10)]
})
fake_df
# Out:
#                nome data_nascimento                          email
# 0      Lindsey Ward      1973-07-13          zwilliams@example.com
# 1  Kristin Mitchell      1999-09-20  nicholashernandez@example.com
# 2  Erica Cunningham      2010-05-25       rogersthomas@example.net
# 3  Catherine Bishop      2006-02-10              jwong@example.net
# 4    Robert Meadows      2012-04-13        matthewwebb@example.com
# 5     Paul Cardenas      1994-12-24            david02@example.com
# 6  Stephanie Thomas      2010-03-30             hbrown@example.org
# 7         Gary Chen      1999-05-03         wcastaneda@example.net
# 8        David Rush      2012-08-22           kcarlson@example.net
# 9     Morgan Thomas      2006-08-15        juliabarnes@example.com

# %%
fake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nome             10 non-null     object
#  1   data_nascimento  10 non-null     object
#  2   email            10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %% [markdown]
# ##### Converter a coluna data nascimento para datetime e filtrar os nascidos depois do ano 2000

# %%
fake_df['data_nascimento'] = pd.to_datetime(fake_df['data_nascimento'])

fake_df
# Out:
#                nome data_nascimento                          email
# 0      Lindsey Ward      1973-07-13          zwilliams@example.com
# 1  Kristin Mitchell      1999-09-20  nicholashernandez@example.com
# 2  Erica Cunningham      2010-05-25       rogersthomas@example.net
# 3  Catherine Bishop      2006-02-10              jwong@example.net
# 4    Robert Meadows      2012-04-13        matthewwebb@example.com
# 5     Paul Cardenas      1994-12-24            david02@example.com
# 6  Stephanie Thomas      2010-03-30             hbrown@example.org
# 7         Gary Chen      1999-05-03         wcastaneda@example.net
# 8        David Rush      2012-08-22           kcarlson@example.net
# 9     Morgan Thomas      2006-08-15        juliabarnes@example.com

# %%
fake_df[fake_df['data_nascimento'] > '2000-01-01 00:00:00']
# Out:
#                nome data_nascimento                     email
# 2  Erica Cunningham      2010-05-25  rogersthomas@example.net
# 3  Catherine Bishop      2006-02-10         jwong@example.net
# 4    Robert Meadows      2012-04-13   matthewwebb@example.com
# 6  Stephanie Thomas      2010-03-30        hbrown@example.org
# 8        David Rush      2012-08-22      kcarlson@example.net
# 9     Morgan Thomas      2006-08-15   juliabarnes@example.com

# %%
fake_df[fake_df['data_nascimento'].dt.year>2000]
# Out:
#                nome data_nascimento                     email
# 2  Erica Cunningham      2010-05-25  rogersthomas@example.net
# 3  Catherine Bishop      2006-02-10         jwong@example.net
# 4    Robert Meadows      2012-04-13   matthewwebb@example.com
# 6  Stephanie Thomas      2010-03-30        hbrown@example.org
# 8        David Rush      2012-08-22      kcarlson@example.net
# 9     Morgan Thomas      2006-08-15   juliabarnes@example.com

# %%
fake_df.query("data_nascimento > '2000-01-01 00:00:00'")
# Out:
#                nome data_nascimento                     email
# 2  Erica Cunningham      2010-05-25  rogersthomas@example.net
# 3  Catherine Bishop      2006-02-10         jwong@example.net
# 4    Robert Meadows      2012-04-13   matthewwebb@example.com
# 6  Stephanie Thomas      2010-03-30        hbrown@example.org
# 8        David Rush      2012-08-22      kcarlson@example.net
# 9     Morgan Thomas      2006-08-15   juliabarnes@example.com

# %% [markdown]
# ### Com o seguinte dataset realize as operações a seguir:
#
# Fonte de dados: https://www.kaggle.com/datasets/dgoenrique/disney-movies-and-tv-shows
#
# - Mostrar o resumo dos dados
#
# - Exibir o total de valores nulos para cada coluna
#
# - Exibir o total de duplicados

# %%
path_disney = '../data_analytics_engineering/dados/aula2/disney/titles.csv'

disney_df = pd.read_csv(path_disney, encoding="ansi")

# Mostrar o resumo dos dados
disney_df.head()
# Out:
#         id                                   title   type
# 0  tm89464                  Miracle on 34th Street  MOVIE  \
# 1  tm61729  The Adventures of Ichabod and Mr. Toad  MOVIE
# 2  tm61052                              Cinderella  MOVIE
# 3  tm87946                                   Dumbo  MOVIE
# 4  tm74391                                Fantasia  MOVIE
#
#                                          description  release_year
# 0  Kris Kringle, seemingly the embodiment of Sant...          1947  \
# 1  The Wind in the Willows: Concise version of Ke...          1950
# 2  Cinderella has faith her dreams of a better li...          1950
# 3  Dumbo is a baby elephant born with over-sized ...          1941
# 4  Walt Disney's timeless masterpiece is an extra...          1941
#
#   age_certification  runtime
# 0                 G       96  \
# 1                 G       68
# 2                 G       74
# 3                 G       64
# 4                 G      119
#
# ...

# %%
# Mostrar o resumo dos dados
disney_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854 entries, 0 to 1853
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1854 non-null   object
#  1   title                 1854 non-null   object
#  2   type                  1854 non-null   object
#  3   description           1845 non-null   object
#  4   release_year          1854 non-null   int64
#  5   age_certification     1403 non-null   object
#  6   runtime               1854 non-null   int64
#  7   genres                1854 non-null   object
#  8   production_countries  1854 non-null   object
#  9   seasons               540 non-null    float64
#  10  imdb_id               1376 non-null   object
#  11  imdb_score            1339 non-null   float64
#  12  imdb_votes            1328 non-null   float64
#  13  tmdb_popularity       1839 non-null   float64
#  14  tmdb_score            1708 non-null   float64
# ...

# %%
# Mostrar o resumo dos dados
disney_df.describe()
# Out:
#        release_year      runtime     seasons   imdb_score    imdb_votes
# count   1854.000000  1854.000000  540.000000  1339.000000  1.328000e+03  \
# mean    2006.193635    59.206580    2.618519     6.620687  6.961624e+04
# std       20.629561    38.566305    3.268281     1.066208  1.846213e+05
# min     1928.000000     1.000000    1.000000     1.600000  5.000000e+00
# 25%     2002.000000    24.000000    1.000000     5.950000  3.267500e+02
# 50%     2014.000000    48.000000    2.000000     6.700000  3.228000e+03
# 75%     2020.000000    91.000000    3.000000     7.400000  3.273050e+04
# max     2023.000000   182.000000   36.000000     9.500000  1.403757e+06
#
#        tmdb_popularity   tmdb_score
# count      1839.000000  1708.000000
# mean         25.745671     6.817494
# std          79.389568     1.165990
# min           0.600000     2.000000
# 25%           2.998500     6.217500
# 50%           9.148000     6.873000
# 75%          23.152500     7.500000
# ...

# %%
# Exibir o total de valores nulos para cada coluna
disney_df.isna().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description                9
# release_year               0
# age_certification        451
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 1314
# imdb_id                  478
# imdb_score               515
# imdb_votes               526
# tmdb_popularity           15
# tmdb_score               146
# dtype: int64

# %%
# Exibir o total de duplicados
disney_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Harmonizando dados
#
# - Fonte de dados: https://www.imdb.com/interfaces/
# - Repositório: `dados/harmonizacao/rating_data.tsv`

# %%
path_harmonizacao = '../data_analytics_engineering/dados/aula2/harmonizacao/rating_data.tsv'

# CVS é separado por , e o TSV é separado por Tab "\t"
harmonizacao_df = pd.read_csv(path_harmonizacao, sep='\t')
harmonizacao_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1959
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1797
# 3        tt0000004            5.6       179
# 4        tt0000005            6.2      2596
# ...            ...            ...       ...
# 1289853  tt9916730            8.3        10
# 1289854  tt9916766            7.0        21
# 1289855  tt9916778            7.2        36
# 1289856  tt9916840            8.8         6
# 1289857  tt9916880            8.2         6
#
# [1289858 rows x 3 columns]
